# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the data
file_path = '/Users/kritikasethi10/Desktop/ml-project/ml-semper-fortis/Datasets/B0006_converted.csv'
df = pd.read_csv(file_path)

# %%
# Shape and data types
print(f"Shape of the dataset: {df.shape}")
print(df.dtypes)
# Out:
# Shape of the dataset: (604802, 19)
# Voltage_measured        float64
# Current_measured        float64
# Temperature_measured    float64
# Current_charge          float64
# Voltage_charge          float64
# Time                    float64
# Cycle_type               object
# Ambient_temperature       int64
# Timestamp                object
# Current_load            float64
# Voltage_load            float64
# Capacity                float64
# Sense_current            object
# Battery_current          object
# Current_ratio            object
# Battery_impedance        object
# Rectified_Impedance      object
# Re                      float64
# Rct                     float64
# dtype: object

# %%
df.head()
# Out:
#    Voltage_measured  Current_measured  Temperature_measured  Current_charge  \
# 0          3.864624          0.000082             24.682214          -0.001
# 1          3.469113         -4.059185             24.695407          -4.060
# 2          3.994806          1.513750             24.711491           1.506
# 3          4.005888          1.511389             24.739672           1.506
# 4          4.012944          1.510817             24.753180           1.506
#
#    Voltage_charge    Time Cycle_type  Ambient_temperature  \
# 0          -0.007   0.000     charge                   24
# 1           1.558   2.532     charge                   24
# 2           4.710   5.500     charge                   24
# 3           4.726   8.344     charge                   24
# 4           4.737  11.125     charge                   24
#
#                  Timestamp  Current_load  Voltage_load  Capacity  \
# 0  2008-04-02 13:08:17.921           NaN           NaN       NaN
# 1                      NaN           NaN           NaN       NaN
# 2                      NaN           NaN           NaN       NaN
# 3                      NaN           NaN           NaN       NaN
# 4                      NaN           NaN           NaN       NaN
#
#   Sense_current Battery_current Current_ratio Battery_impedance  \
# 0           NaN             NaN           NaN               NaN
# 1           NaN             NaN           NaN               NaN
# 2           NaN             NaN           NaN               NaN
# 3           NaN             NaN           NaN               NaN
# 4           NaN             NaN           NaN               NaN
#
#   Rectified_Impedance  Re  Rct
# 0                 NaN NaN  NaN
# 1                 NaN NaN  NaN
# 2                 NaN NaN  NaN
# 3                 NaN NaN  NaN
# 4                 NaN NaN  NaN

# %%
# Summary statistics
print(df.describe())
# Out:
#        Voltage_measured  Current_measured  Temperature_measured  \
# count     591458.000000     591458.000000         591458.000000
# mean           4.104234          0.359343             26.429154
# std            0.224811          0.884314              2.794788
# min           -0.001422         -4.480834             22.984099
# 25%            4.154358          0.055642             24.501277
# 50%            4.197002          0.186089             25.558404
# 75%            4.199247          1.050413             27.611183
# max            8.083344          1.530124             42.007540
#
#        Current_charge  Voltage_charge           Time  Ambient_temperature  \
# count   541173.000000   541173.000000  591458.000000             604802.0
# mean         0.555134        4.428673    4763.856934                 24.0
# std          0.591993        0.348270    3147.859026                  0.0
# min         -4.480000       -0.007000       0.000000                 24.0
# 25%          0.077000        4.246000    1928.175750                 24.0
# 50%          0.232000        4.322000    4467.515500                 24.0
# 75%          1.212000        4.672000    7503.824000                 24.0
# max          1.507000        4.996000   10807.328000                 24.0
#
#        Current_load  Voltage_load    Capacity            Re           Rct
# count  50285.000000  50285.000000  168.000000  13344.000000  13344.000000
# mean       1.306434      2.262837    1.546851      0.070052      0.093020
# std        1.348294      0.851166    0.252038      0.004906      0.007368
# min       -1.999200      0.000000    1.153818      0.059131      0.077956
# 25%        1.998800      2.330000    1.347427      0.065903      0.086328
# 50%        1.999000      2.525000    1.485372      0.071774      0.094452
# 75%        1.999000      2.693000    1.767208      0.073906      0.098046
# max        1.999200      4.238000    2.035338      0.079141      0.106684

# %%
columns = ['Voltage_measured', 'Current_measured', 'Temperature_measured', 'Capacity']

for column in columns:
    plt.figure(figsize=(10, 6))
    sns.histplot(df[column], kde=True)
    plt.title(f'{column} Distribution')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()
