# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the data
file_path = '/Users/kritikasethi10/Desktop/ml-project/ml-semper-fortis/Datasets/B0007_converted.csv'
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#    Voltage_measured  Current_measured  Temperature_measured  Current_charge  \
# 0          3.866123         -0.003830             24.434244         -0.0006
# 1          3.644900         -2.261867             24.441053         -2.2697
# 2          4.001099          1.489161             24.445727          1.4995
# 3          4.011041          1.491029             24.459603          1.4995
# 4          4.017485          1.491413             24.458385          1.4995
#
#    Voltage_charge    Time Cycle_type  Ambient_temperature  \
# 0           0.002   0.000     charge                   24
# 1           2.576   2.532     charge                   24
# 2           4.719   5.500     charge                   24
# 3           4.745   8.344     charge                   24
# 4           4.745  11.125     charge                   24
#
#                  Timestamp  Current_load  Voltage_load  Capacity  \
# 0  2008-04-02 13:08:17.921           NaN           NaN       NaN
# 1                      NaN           NaN           NaN       NaN
# 2                      NaN           NaN           NaN       NaN
# 3                      NaN           NaN           NaN       NaN
# 4                      NaN           NaN           NaN       NaN
#
#   Sense_current Battery_current Current_ratio Battery_impedance  \
# 0           NaN             NaN           NaN               NaN
# 1           NaN             NaN           NaN               NaN
# 2           NaN             NaN           NaN               NaN
# 3           NaN             NaN           NaN               NaN
# 4           NaN             NaN           NaN               NaN
#
#   Rectified_Impedance  Re  Rct
# 0                 NaN NaN  NaN
# 1                 NaN NaN  NaN
# 2                 NaN NaN  NaN
# 3                 NaN NaN  NaN
# 4                 NaN NaN  NaN

# %%
# Summary statistics
print(df.describe())
# Out:
#        Voltage_measured  Current_measured  Temperature_measured  \
# count     591458.000000     591458.000000         591458.000000
# mean           4.099742          0.386975             26.119363
# std            0.220993          0.927493              2.720203
# min            0.002932         -2.261867             22.969923
# 25%            4.053077          0.042134             24.264849
# 50%            4.209444          0.197802             25.299190
# 75%            4.212002          1.487893             27.051967
# max            8.332909          1.507169             42.332522
#
#        Current_charge  Voltage_charge           Time  Ambient_temperature  \
# count   541173.000000   541173.000000  591458.000000             604802.0
# mean         0.604506        4.002228    4763.856934                 24.0
# std          0.627515        1.417514    3147.859026                  0.0
# min         -2.269700        0.002000       0.000000                 24.0
# 25%          0.067500        4.263000    1928.175750                 24.0
# 50%          0.257200        4.352000    4467.515500                 24.0
# 75%          1.499500        4.694000    7503.824000                 24.0
# max          1.500000        4.998000   10807.328000                 24.0
#
#        Current_load  Voltage_load    Capacity            Re           Rct
# count  50285.000000  50285.000000  168.000000  13344.000000  13344.000000
# mean       1.471671      2.499169    1.644421      0.052807      0.076874
# std        1.294697      0.550780    0.160950      0.007985      0.008384
# min       -2.000000      0.000000    1.400455      0.035920      0.060073
# 25%        2.000000      2.470000    1.498058      0.048124      0.070838
# 50%        2.000000      2.582000    1.616125      0.053367      0.076233
# 75%        2.000000      2.743000    1.812005      0.057703      0.082198
# max        2.000000      4.249000    1.891052      0.067294      0.093572

# %%
df.shape
# Out:
# (604802, 19)

# %%
columns = ['Voltage_measured', 'Current_measured', 'Temperature_measured', 'Capacity']

for column in columns:
    plt.figure(figsize=(10, 6))
    sns.histplot(df[column], kde=True)
    plt.title(f'{column} Distribution')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()
