# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the data
file_path = '/Users/kritikasethi10/Desktop/ml-project/ml-semper-fortis/Datasets/B0005_converted.csv'
df = pd.read_csv(file_path)

# %%
# Shape and data types
print(f"Shape of the dataset: {df.shape}")
print(df.dtypes)
# Out:
# Shape of the dataset: (604802, 19)
# Voltage_measured        float64
# Current_measured        float64
# Temperature_measured    float64
# Current_charge          float64
# Voltage_charge          float64
# Time                    float64
# Cycle_type               object
# Ambient_temperature       int64
# Timestamp                object
# Current_load            float64
# Voltage_load            float64
# Capacity                float64
# Sense_current            object
# Battery_current          object
# Current_ratio            object
# Battery_impedance        object
# Rectified_Impedance      object
# Re                      float64
# Rct                     float64
# dtype: object

# %%
df.head()
# Out:
#    Voltage_measured  Current_measured  Temperature_measured  Current_charge  \
# 0          3.873017         -0.001201             24.655358           0.000
# 1          3.479394         -4.030268             24.666480          -4.036
# 2          4.000588          1.512731             24.675394           1.500
# 3          4.012395          1.509063             24.693865           1.500
# 4          4.019708          1.511318             24.705069           1.500
#
#    Voltage_charge    Time Cycle_type  Ambient_temperature  \
# 0           0.003   0.000     charge                   24
# 1           1.570   2.532     charge                   24
# 2           4.726   5.500     charge                   24
# 3           4.742   8.344     charge                   24
# 4           4.753  11.125     charge                   24
#
#                  Timestamp  Current_load  Voltage_load  Capacity  \
# 0  2008-04-02 13:08:17.921           NaN           NaN       NaN
# 1                      NaN           NaN           NaN       NaN
# 2                      NaN           NaN           NaN       NaN
# 3                      NaN           NaN           NaN       NaN
# 4                      NaN           NaN           NaN       NaN
#
#   Sense_current Battery_current Current_ratio Battery_impedance  \
# 0           NaN             NaN           NaN               NaN
# 1           NaN             NaN           NaN               NaN
# 2           NaN             NaN           NaN               NaN
# 3           NaN             NaN           NaN               NaN
# 4           NaN             NaN           NaN               NaN
#
#   Rectified_Impedance  Re  Rct
# 0                 NaN NaN  NaN
# 1                 NaN NaN  NaN
# 2                 NaN NaN  NaN
# 3                 NaN NaN  NaN
# 4                 NaN NaN  NaN

# %%
# Summary statistics
print(df.describe())
# Out:
#        Voltage_measured  Current_measured  Temperature_measured  \
# count     591458.000000     591458.000000         591458.000000
# mean           4.103945          0.369404             26.369701
# std            0.213469          0.907558              2.772424
# min            0.003365         -4.479660             23.214802
# 25%            4.089426          0.040636             24.488485
# 50%            4.205140          0.171961             25.479630
# 75%            4.205908          1.259778             27.348768
# max            8.393141          1.531301             41.450232
#
#        Current_charge  Voltage_charge           Time  Ambient_temperature  \
# count   541173.000000   541173.000000  591458.000000             604802.0
# mean         0.566810        4.184427    4763.856934                 24.0
# std          0.616015        1.112792    3147.859026                  0.0
# min         -4.468000        0.003000       0.000000                 24.0
# 25%          0.057000        4.250000    1928.175750                 24.0
# 50%          0.225000        4.332000    4467.515500                 24.0
# 75%          1.498000        4.688000    7503.824000                 24.0
# max          1.500000        5.002000   10807.328000                 24.0
#
#        Current_load  Voltage_load    Capacity            Re           Rct
# count  50285.000000  50285.000000  168.000000  13344.000000  13344.000000
# mean       1.362700      2.308406    1.572502      0.054245      0.077340
# std        1.313698      0.800300    0.190413      0.005480      0.006356
# min       -1.998400      0.000000    1.287453      0.043559      0.064883
# 25%        1.998000      2.388000    1.390021      0.049159      0.071464
# 50%        1.998200      2.533000    1.557085      0.055850      0.077487
# 75%        1.998200      2.690000    1.769163      0.058820      0.082576
# max        1.998400      4.238000    1.856487      0.063516      0.089757

# %%
columns = ['Voltage_measured', 'Current_measured', 'Temperature_measured', 'Capacity']

for column in columns:
    plt.figure(figsize=(10, 6))
    sns.histplot(df[column], kde=True)
    plt.title(f'{column} Distribution')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()
