# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the data
file_path = '/Users/kritikasethi10/Desktop/ml-project/ml-semper-fortis/Datasets/Cleaned Stage 3/B0018_no_outliers.csv'
df = pd.read_csv(file_path)

# %%
# Shape and data types
print(f"Shape of the dataset: {df.shape}")
print(df.dtypes)
# Out:
# Shape of the dataset: (314676, 13)
# Cycle_type_charge         int64
# Cycle_type_discharge      int64
# Voltage_measured        float64
# Current_measured        float64
# Temperature_measured    float64
# Current_charge          float64
# Voltage_charge          float64
# Time                    float64
# Ambient_temperature       int64
# Current_load            float64
# Voltage_load            float64
# Capacity                float64
# Cycle_Number              int64
# dtype: object

# %%
df.head()
# Out:
#    Cycle_type_charge  Cycle_type_discharge  Voltage_measured  \
# 0                  1                     0          4.197493
# 1                  1                     0          4.197493
# 2                  1                     0          4.197493
# 3                  1                     0          4.197493
# 4                  1                     0          4.197493
#
#    Current_measured  Temperature_measured  Current_charge  Voltage_charge  \
# 0          0.001014             23.735721           0.000          4.2865
# 1          0.131125             23.743956           0.130          4.2865
# 2          1.517435             23.773723           1.507          4.7210
# 3          1.514558             23.777077           1.507          4.7370
# 4          1.517284             23.792710           1.507          4.7430
#
#      Time  Ambient_temperature  Current_load  Voltage_load  Capacity  \
# 0   0.000                   24           NaN           NaN  1.855005
# 1   2.484                   24           NaN           NaN  1.855005
# 2   5.109                   24           NaN           NaN  1.855005
# 3   7.562                   24           NaN           NaN  1.855005
# 4  10.062                   24           NaN           NaN  1.855005
#
#    Cycle_Number
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1

# %%
# Summary statistics
print(df.describe())
# Out:
#        Cycle_type_charge  Cycle_type_discharge  Voltage_measured  \
# count      314676.000000         314676.000000     314674.000000
# mean            0.889200              0.110800          4.098160
# std             0.313884              0.313884          0.237589
# min             0.000000              0.000000          2.278634
# 25%             1.000000              0.000000          4.188384
# 50%             1.000000              0.000000          4.197300
# 75%             1.000000              0.000000          4.199208
# max             1.000000              1.000000          4.253586
#
#        Current_measured  Temperature_measured  Current_charge  Voltage_charge  \
# count     314674.000000         314674.000000   279810.000000   279810.000000
# mean           0.287727             25.913199        0.569561        4.438550
# std            1.002152              2.989441        0.621917        0.225334
# min           -4.508828             21.810170       -4.513000        1.396000
# 25%            0.036304             23.617034        0.057000        4.246000
# 50%            0.158090             24.840642        0.224000        4.338000
# 75%            1.208289             27.520903        1.507000        4.651000
# max            1.536047             38.878688        1.507000        4.996000
#
#                 Time  Ambient_temperature  Current_load  Voltage_load  \
# count  314676.000000             314676.0  34866.000000  34866.000000
# mean     4722.178797                 24.0      1.998679      2.612647
# std      3111.160007                  0.0      0.000117      0.241842
# min         0.000000                 24.0      1.998400      1.449000
# 25%      1946.809000                 24.0      1.998600      2.509000
# 50%      4387.703000                 24.0      1.998600      2.606000
# 75%      7426.613000                 24.0      1.998800      2.751000
# max     10815.375000                 24.0      1.999000      4.209000
#
#             Capacity   Cycle_Number
# count  314676.000000  314676.000000
# mean        1.599436     113.496549
# std         0.159164      76.195601
# min         1.341051       1.000000
# 25%         1.442536      45.000000
# 50%         1.616416     105.000000
# 75%         1.732770     176.000000
# max         1.855005     264.000000

# %%
columns = ['Voltage_measured', 'Current_measured', 'Temperature_measured', 'Capacity']

for column in columns:
    plt.figure(figsize=(10, 6))
    sns.histplot(df[column], kde=True)
    plt.title(f'{column} Distribution')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# before smoothing
plt.figure(figsize=(14, 8))
plt.plot(df['Cycle_Number'], df['Capacity'], label='Capacity')
plt.title('Capacity vs. Cycle Number')
plt.xlabel('Cycle Number')
plt.ylabel('Capacity (Ahr)')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['Time'], df['Voltage_measured'])
plt.xlabel('Time')
plt.ylabel('Voltage (V)')
plt.title('Voltage vs. Time')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['Time'], df['Current_measured'])
plt.xlabel('Time')
plt.ylabel('Current (A)')
plt.title('Current vs. Time')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['Time'], df['Temperature_measured'], label='Battery Temperature')
plt.plot(df['Time'], df['Ambient_temperature'], label='Ambient Temperature')
plt.xlabel('Time')
plt.ylabel('Temperature (°C)')
plt.title('Temperature vs. Time')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['Voltage_measured'], df['Current_measured'])
plt.xlabel('Voltage (V)')
plt.ylabel('Current (A)')
plt.title('Current vs. Voltage')
plt.show()
