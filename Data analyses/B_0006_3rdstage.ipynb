# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the data
file_path = '/Users/kritikasethi10/Desktop/ml-project/ml-semper-fortis/Datasets/Cleaned Stage 3/B0006_no_outliers.csv'
df = pd.read_csv(file_path)

# %%
# Shape and data types
print(f"Shape of the dataset: {df.shape}")
print(df.dtypes)
# Out:
# Shape of the dataset: (591458, 13)
# Cycle_type_charge         int64
# Cycle_type_discharge      int64
# Voltage_measured        float64
# Current_measured        float64
# Temperature_measured    float64
# Current_charge          float64
# Voltage_charge          float64
# Time                    float64
# Ambient_temperature       int64
# Current_load            float64
# Voltage_load            float64
# Capacity                float64
# Cycle_Number              int64
# dtype: object

# %%
df.head()
# Out:
#    Cycle_type_charge  Cycle_type_discharge  Voltage_measured  \
# 0                  1                     0          4.198689
# 1                  1                     0          4.198689
# 2                  1                     0          4.198689
# 3                  1                     0          4.198689
# 4                  1                     0          4.198689
#
#    Current_measured  Temperature_measured  Current_charge  Voltage_charge  \
# 0          0.000082             24.682214          -0.001           4.446
# 1         -4.059185             24.695407          -4.060           1.558
# 2          1.513750             24.711491           1.506           4.710
# 3          1.511389             24.739672           1.506           4.726
# 4          1.510817             24.753180           1.506           4.737
#
#      Time  Ambient_temperature  Current_load  Voltage_load  Capacity  \
# 0   0.000                   24           NaN           NaN  2.035338
# 1   2.532                   24           NaN           NaN  2.035338
# 2   5.500                   24           NaN           NaN  2.035338
# 3   8.344                   24           NaN           NaN  2.035338
# 4  11.125                   24           NaN           NaN  2.035338
#
#    Cycle_Number
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1

# %%
# Summary statistics
print(df.describe())
# Out:
#        Cycle_type_charge  Cycle_type_discharge  Voltage_measured  \
# count      591458.000000         591458.000000     591458.000000
# mean            0.914981              0.085019          4.120337
# std             0.278910              0.278910          0.223620
# min             0.000000              0.000000         -0.001422
# 25%             1.000000              0.000000          4.196076
# 50%             1.000000              0.000000          4.197858
# 75%             1.000000              0.000000          4.199247
# max             1.000000              1.000000          4.985345
#
#        Current_measured  Temperature_measured  Current_charge  Voltage_charge  \
# count     591458.000000         591458.000000   541173.000000   541173.000000
# mean           0.339254             26.429154        0.555186        4.443559
# std            0.914552              2.794788        0.591787        0.237001
# min           -4.480834             22.984099       -4.480000       -0.007000
# 25%            0.055643             24.501277        0.077000        4.246000
# 50%            0.186089             25.558404        0.232000        4.322000
# 75%            1.050413             27.611183        1.212000        4.672000
# max            1.530124             42.007540        1.507000        4.996000
#
#                 Time  Ambient_temperature  Current_load  Voltage_load  \
# count  591458.000000             591458.0  50285.000000  50285.000000
# mean     4763.856934                 24.0      1.535854      2.384025
# std      3147.859026                  0.0      1.279502      0.685677
# min         0.000000                 24.0     -1.999200      0.000000
# 25%      1928.175750                 24.0      1.998800      2.380000
# 50%      4467.515500                 24.0      1.999000      2.539000
# 75%      7503.824000                 24.0      1.999000      2.693000
# max     10807.328000                 24.0      1.999200      4.238000
#
#             Capacity   Cycle_Number
# count  591458.000000  591458.000000
# mean        1.494186     187.250322
# std         0.215529      85.668908
# min         1.153818       1.000000
# 25%         1.325930     117.000000
# 50%         1.451836     188.000000
# 75%         1.651121     261.000000
# max         2.035338     335.000000

# %%
columns = ['Voltage_measured', 'Current_measured', 'Temperature_measured', 'Capacity']

for column in columns:
    plt.figure(figsize=(10, 6))
    sns.histplot(df[column], kde=True)
    plt.title(f'{column} Distribution')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# before smoothing
plt.figure(figsize=(14, 8))
plt.plot(df['Cycle_Number'], df['Capacity'], label='Capacity')
plt.title('Capacity vs. Cycle Number')
plt.xlabel('Cycle Number')
plt.ylabel('Capacity (Ahr)')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['Time'], df['Voltage_measured'])
plt.xlabel('Time')
plt.ylabel('Voltage (V)')
plt.title('Voltage vs. Time')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['Time'], df['Current_measured'])
plt.xlabel('Time')
plt.ylabel('Current (A)')
plt.title('Current vs. Time')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['Time'], df['Temperature_measured'], label='Battery Temperature')
plt.plot(df['Time'], df['Ambient_temperature'], label='Ambient Temperature')
plt.xlabel('Time')
plt.ylabel('Temperature (°C)')
plt.title('Temperature vs. Time')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['Voltage_measured'], df['Current_measured'])
plt.xlabel('Voltage (V)')
plt.ylabel('Current (A)')
plt.title('Current vs. Voltage')
plt.show()
