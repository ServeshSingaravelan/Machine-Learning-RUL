# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the data
file_path = '/Users/kritikasethi10/Desktop/ml-project/ml-semper-fortis/Datasets/B0018_converted.csv'
df = pd.read_csv(file_path)

# %%
df.shape
# Out:
# (317220, 19)

# %%
df.head()
# Out:
#    Voltage_measured  Current_measured  Temperature_measured  Current_charge  \
# 0          3.865713          0.001014             23.735721           0.000
# 1          3.447651         -4.034445             23.743956          -4.036
# 2          4.005559          1.517435             23.773723           1.507
# 3          4.015989          1.514558             23.777077           1.507
# 4          4.023230          1.517284             23.792710           1.507
#
#    Voltage_charge    Time Cycle_type  Ambient_temperature  \
# 0          -0.007   0.000     charge                   24
# 1           1.553   2.484     charge                   24
# 2           4.721   5.109     charge                   24
# 3           4.737   7.562     charge                   24
# 4           4.743  10.062     charge                   24
#
#                  Timestamp Sense_current Battery_current Current_ratio  \
# 0  2008-07-07 12:26:45.750           NaN             NaN           NaN
# 1                      NaN           NaN             NaN           NaN
# 2                      NaN           NaN             NaN           NaN
# 3                      NaN           NaN             NaN           NaN
# 4                      NaN           NaN             NaN           NaN
#
#   Battery_impedance Rectified_Impedance  Re  Rct  Current_load  Voltage_load  \
# 0               NaN                 NaN NaN  NaN           NaN           NaN
# 1               NaN                 NaN NaN  NaN           NaN           NaN
# 2               NaN                 NaN NaN  NaN           NaN           NaN
# 3               NaN                 NaN NaN  NaN           NaN           NaN
# 4               NaN                 NaN NaN  NaN           NaN           NaN
#
#    Capacity
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
# Summary statistics
print(df.describe())
# Out:
#        Voltage_measured  Current_measured  Temperature_measured  \
# count     314674.000000     314674.000000         314674.000000
# mean           4.076628          0.306064             25.913199
# std            0.241513          0.978067              2.989441
# min            2.278634         -4.508828             21.810170
# 25%            4.048386          0.036304             23.617034
# 50%            4.196494          0.158090             24.840642
# 75%            4.199208          1.208289             27.520903
# max            4.299586          1.536047             38.878688
#
#        Current_charge  Voltage_charge           Time  Ambient_temperature  \
# count   279810.000000   279810.000000  314676.000000             317220.0
# mean         0.569547        4.218308    4722.178797                 24.0
# std          0.621977        0.999241    3111.160007                  0.0
# min         -4.513000       -0.007000       0.000000                 24.0
# 25%          0.057000        4.235000    1946.809000                 24.0
# 50%          0.224000        4.316000    4387.703000                 24.0
# 75%          1.507000        4.651000    7426.613000                 24.0
# max          1.507000        4.996000   10815.375000                 24.0
#
#                 Re          Rct  Current_load  Voltage_load    Capacity
# count  2544.000000  2544.000000  34866.000000  34866.000000  132.000000
# mean      0.062976     0.089090      1.833923      2.408419    1.557701
# std       0.001758     0.003539      0.549609      0.744116    0.154885
# min       0.059112     0.083811      0.000400      0.000000    1.341051
# 25%       0.061802     0.086807      1.998600      2.459000    1.415288
# 50%       0.062760     0.088473      1.998600      2.589000    1.531892
# 75%       0.064317     0.091392      1.998800      2.751000    1.684936
# max       0.066069     0.102295      1.999000      4.209000    1.855005

# %%
columns = ['Voltage_measured', 'Current_measured', 'Temperature_measured', 'Capacity']

for column in columns:
    plt.figure(figsize=(10, 6))
    sns.histplot(df[column], kde=True)
    plt.title(f'{column} Distribution')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()
